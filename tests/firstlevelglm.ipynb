# %%
from src.my_settings import settings
from src.glm import firstlevel
sett = settings()

# %%
# use only subject one
sett["sub_labels"] = ['22']

sett["sub_labels"]
# Out:
# ['22']

# %%
#firstlevel(sett, 'nf', 0.008, ['MotorImagery - Rest'], ["MotorImageryMinusRest"])

# %%
# view 
from nilearn.plotting import view_img
from nilearn.glm import threshold_stats_img

map, thres = threshold_stats_img("/Volumes/T7/BIDS-MUSICNF/derivatives/nilearn-glm/sub-22_task-nf_stat-z_con-MotorImageryTwoMinusRest.nii.gz",
                    alpha = 0.05, height_control='fdr')

view_img(map)
# Out:
# /opt/anaconda3/envs/musicnf-novelinterface/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:870: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /opt/anaconda3/envs/musicnf-novelinterface/lib/python3.13/site-packages/nilearn/plotting/html_document.py:102: UserWarning: It seems you have created more than 10 nilearn views. As each view uses dozens of megabytes of RAM, you might want to delete some of them.
#   warnings.warn(
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
# ...

# %%
map, thres = threshold_stats_img("/Volumes/T7/BIDS-MUSICNF/derivatives/nilearn-glm/sub-22_task-nf_stat-z_con-MotorImageryMinusRest.nii.gz",
                    alpha = 0.05, height_control='fdr')

view_img(map)
# Out:
# /opt/anaconda3/envs/musicnf-novelinterface/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:870: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;background&quot;
#         /&gt;
#         &lt;!-- the colormap --&gt;
#         &lt;img
# ...
